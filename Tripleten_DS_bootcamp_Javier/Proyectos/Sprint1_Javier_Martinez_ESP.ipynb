# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor Iteración 2.</b>
#
# # Comentario General #2
#
# Hola, Javier.
#
# Me presento: soy David Bautista, el revisor humano que te acompañará en el proceso de revisión del proyecto después de la ayuda inicial de Dot.
# En pocas palabras, quiero felicitarte por las modificaciones realizadas; he dejado algunos comentarios como retroalimentación sobre los puntos que habia que reforzar tras la primera iteración.
# Asimismo, te felicito por la culminación del proyecto y te deseo mucho ánimo en la continuación de este proceso de aprendizaje.
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # Proyecto 1 — Primera Fase
#
# Como parte del equipo de análisis de Store 1, comenzarás trabajando con datos de clientes y sus compras.
#
# Tu tarea es limpiar y preparar estos datos para que puedan ser utilizados en futuros análisis de negocio orientados a identificar clientes leales, analizar ingresos por categoría y buscar oportunidades de marketing.
#
# ---

# %% [markdown]
# ## Paso 1
#
# Store 1 está revisando la calidad y coherencia de sus datos de clientes. Para evitar duplicados y asegurar consistencia en el registro de clientes, es necesario limpiar los nombres eliminando espacios y símbolos innecesarios.
#
# En este primer paso, trabajarás con un nombre de usuario que presenta errores de formato:
#
# * Espacios adicionales al inicio y al final.
# * El guion bajo (`_`) usado como separador entre el nombre y el apellido.
#
# **Tarea:**
#
# 1. Limpia el dato eliminando los espacios innecesarios en la variable `usuario_nombre`.
# 2. Reemplaza el guion bajo por un espacio.

# %%
usuario_nombre = ' mike_reed '

# 1. Limpia el dato eliminando los espacios innecesarios en la variable user_name
usuario_nombre = usuario_nombre.strip()# llamamos a la función strip para que modifique el string

# 2. Reemplaza el guion bajo por un espacio.
usuario_nombre = usuario_nombre.replace('_',' ')# Indico a la f replace el caracter que quiero sustiuir por el caracter espacio

print(usuario_nombre)
# Out:
# mike reed

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo: usar `strip()` para eliminar los espacios en blanco alrededor y `replace('_', ' ')` para corregir el separador produce el nombre correctamente limpiado.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Utiliza el método `strip()` para eliminar los espacios al principio y al final de la cadena.
#
# Utiliza el método `replace()` para sustituir el guion bajo `_` por un espacio.

# %% [markdown]
# ## Paso 2
#
# Después de limpiar el `usuario_nombre`, vamos a seguir procesando el dato. Separar los nombres permitirá personalizar las campañas del programa de fidelización.
#
# **Tarea:**
#
# 1. Dividir el `usuario_nombre` ya corregido en dos partes, para obtener una lista con el nombre y el apellido separados.

# %%
usuario_nombre = 'mike reed'

# 1. Divide el usuario en dos partes: nombre y apellido
usuario_sep = usuario_nombre.split(' ')# Indico a la f split cual es el caracter del string donde hacer las divisiones.

print(usuario_sep)
# Out:
# ['mike', 'reed']

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al dividir el nombre completo limpio en una lista de dos elementos (nombre y apellido) usando `split()`.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Utiliza el método `split()` indicando el carácter separador.

# %% [markdown]
# ## Paso 3
#
# ¡Genial! Para segmentar correctamente a los clientes por edad, es necesario transformar la edad a tipo numérico. Ahora trabajaremos con la variable `usuario_edad`. Su tipo de dato es incorrecto.
#
# **Tarea:**
#
# 1. Convierte el valor al tipo de dato correcto.
# 2. Muestra el resultado.

# %%
usuario_edad = 32.0

# 1. Convierte el valor al tipo de dato correcto
usuario_edad = int(usuario_edad)# utilizo int para indicar que la variable edad se convierta a entero

print(usuario_edad)
# Out:
# 32

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Bien hecho al convertir el valor de la edad a un entero con `int()` e imprimir el resultado esperado.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Usa la función int() para convertir el valor a entero.

# %% [markdown]
# ## Paso 4
#
# Algunos registros contienen edades no válidas. Debemos validar los datos antes del análisis.
#
# **Tarea:**
#
# 1. Escribe un código que intente convertir `usuario_edad` a entero y lo guarde en `usuario_edad_int`.
#
# 2. Si falla, muestra el mensaje:
# `Proporcione su edad como un valor numérico.`

# %%
usuario_edad = 'treinta y dos'
try:
    usuario_edad_int = int(usuario_edad)# 1. Intenta convertir usuario_edad a entero y guárdalo en usuario_edad_int
except:
    print('Proporcione su edad como un valor numérico.')# 2. Si falla, muestra el mensaje correspondiente
# Out:
# Proporcione su edad como un valor numérico.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen uso de `try/except`: intentas la conversión, la guardas en `usuario_edad_int`, y muestras el mensaje requerido cuando la conversión falla.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Usa `try` / `except` para manejar errores al convertir con `int()`.

# %% [markdown]
# ## Paso 5
#
# Ordenar los registros facilita su revisión y permite construir reportes claros para el programa de fidelización.
#
# **Tarea:**
#
# 1. Ordena la lista por el ID de usuario en orden ascendente.

# %%
usuarios = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['ROPA', 'ELECTRÓNICA', 'BELLEZA'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['LIBROS', 'HOGAR', 'DEPORTE'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BELLEZA', 'HOGAR', 'COMIDA'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['ROPA', 'COMIDA', 'BELLEZA'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['DEPORTE', 'ELECTRÓNICA', 'HOGAR'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOGAR', 'LIBROS', 'ROPA'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BELLEZA', 'ROPA', 'ELECTRÓNICA'], [189, 299, 579]],
]

usuarios.sort(key=lambda x:x[0])
print(usuarios)
# Out:
# [['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]], ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]], ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]], ['32761', 'SAMANTHA SMITH', 29.0, ['ROPA', 'ELECTRÓNICA', 'BELLEZA'], [299, 679, 85]], ['32984', 'David White', 41.0, ['LIBROS', 'HOGAR', 'DEPORTE'], [234, 329, 243]], ['33001', 'emily brown', 26.0, ['BELLEZA', 'HOGAR', 'COMIDA'], [213, 659, 79]], ['33767', ' Maria Garcia', 33.0, ['ROPA', 'COMIDA', 'BELLEZA'], [499, 189, 63]], ['33912', 'JOSE MARTINEZ', 22.0, ['DEPORTE', 'ELECTRÓNICA', 'HOGAR'], [259, 549, 109]], ['34009', 'lisa wilson ', 35.0, ['HOGAR', 'LIBROS', 'ROPA'], [329, 189, 329]], ['34278', 'James Lee', 28.0, ['BELLEZA', 'ROPA', 'ELECTRÓNICA'], [189, 299, 579]]]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# El objetivo es ordenar la lista de registros de usuarios por ID de usuario manteniendo `usuarios` como una lista de filas. Concatenar filas con `+` aplana la estructura en una sola lista larga y además elimina un registro (no se incluye el usuario con ID 32761). Considera ordenar la lista original (por ejemplo, con `sort(key=...)` o `sorted(...)`) para que se conserven la estructura de datos y todos los usuarios.
#
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 2</b> <a class="tocSkip"></a>
#
# Buen trabajo con la modificación.
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Puedes utilizar el método `sort()` en la lista de usuarios para ordenarla de forma ascendente.

# %% [markdown]
# ## Paso 6
#
# Para identificar a los mejores clientes, es necesario conocer el gasto total por categorías.
#
# **Tarea:**
#
# 1. Calcula la suma de los gastos del usuario
# 2. Muestra el resultado.

# %%
categorias_fav_low = ['electrónica', 'deporte', 'libros']
gasto_por_categoria = [894, 213, 173]

# 1. Calcula la suma de los gastos del usuario
# suma_total = gasto_por_categoria[0]+gasto_por_categoria[1]+gasto_por_categoria[2]# revisando he podido usar sum()
suma_total = sum(gasto_por_categoria)
media_total = round(suma_total/len(gasto_por_categoria),2) # trasteando con el redondeo

print('La suma total de gastos del usuario es =',suma_total)
print('La media de gastos por aficción es =',media_total)
# Out:
# La suma total de gastos del usuario es = 1280
# La media de gastos por aficción es = 426.67

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo calculando y mostrando el gasto total; usar `sum(gasto_por_categoria)` es un enfoque limpio y escalable.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Utiliza la indexación para sumar los valores. Por ejemplo, si tienes la lista `numeros = [10, 20, 30]`, puedes acceder a los elementos con `numeros[0]`, `numeros[1]`, etc.

# %% [markdown]
# ## Paso 7
#
# Generar resúmenes de cada cliente permite crear reportes ejecutivos rápidos para la dirección.
#
# **Tarea:**
#
# 1. Usa las variables `usuario_id`, `usuario_nombre` y `usuario_edad` para crear la siguiente cadena:
#
#   `El usuario 32415 es Mike, quien tiene 32 años.`

# %%
usuario_id = '32415'
usuario_nombre = ['mike', 'reed']
usuario_edad = 32

# 1. Crea la cadena de resumen del cliente
usuario_nombre[0] = usuario_nombre[0].capitalize() #vale otra función más
usuario_nombre[1] = usuario_nombre[1].capitalize()
usuario_edad=str(usuario_edad)
usuario_info = 'El usuario '+ usuario_id + " es "+ usuario_nombre[0] + ',' + " quien tiene " + usuario_edad +' años.'

print(usuario_info)
# Out:
# El usuario 32415 es Mike, quien tiene 32 años.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Para crear una cadena, puedes utilizar una f-string. Para extraer el nombre de la lista `usuario`, puedes utilizar la segmentación.
#
# Ejemplo:
#
# ```
# nombre = "Luis"
# mensaje = f"Hola, {nombre}!"
# ```

# %% [markdown]
# ## Paso 8
#
# La dirección necesita saber cuántos clientes tiene registrados para medir el alcance del programa.
#
# **Tarea:**
#
# 1. Crea una cadena formateada que muestre la cantidad de clientes registrados:
# `Hemos registrado datos de X clientes.`

# %%
usuarios = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['ROPA', 'ELECTRÓNICA', 'BELLEZA'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['LIBROS', 'HOGAR', 'DEPORTE'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BELLEZA', 'HOGAR', 'COMIDA'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['ROPA', 'COMIDA', 'BELLEZA'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['DEPORTE', 'ELECTRÓNICA', 'HOGAR'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOGAR', 'LIBROS', 'ROPA'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BELLEZA', 'ROPA', 'ELECTRÓNICA'], [189, 299, 579]],
]
numero_de_usuarios = len(usuarios)
usuarios_info = f"Hemos registrado datos de {numero_de_usuarios} clientes."

print(usuarios_info)
# Out:
# Hemos registrado datos de 10 clientes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Genial: `len(usuarios)` más un f-string es una forma clara de generar el mensaje requerido con el número de clientes registrados.
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Para crear una cadena, puedes utilizar una f-string. Para extraer la cantidad de clientes en la lista, puedes utilizar la función que devuelve la longitud de la lista.
#
# Ejemplo:
#
# ```
# nombre = "Luis"
# mensaje = f"Hola, {nombre}!"
# ```

# %% [markdown]
# ## Paso 9
#
# Aplicar la limpieza a todos los registros garantiza consistencia antes de lanzar el programa de fidelización.
#
# **Tarea:**
#
# 1. Elimina los espacios iniciales y finales de los nombres y reemplaza los guiones bajos por espacios.
# 2. Convierte las edades a números enteros.
# 3. Separa los nombres y apellidos en una sublista.
# 4. Guarda el resultado en una nueva lista llamada `usuarios_limpio`
# 5. Muéstrala en pantalla.

# %%
usuarios = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]],
]

usuarios_limpio = [] # asigno el valor de la lista a la lista a limpiar-formatear, según indica el revisor tiene que estar vacia

#Lo que sigue es la secuencia del ejercicio, al darme cuenta de que podia hacer una sola lista de cambios para copiar y pegar solo cambiando indices y nombres
#he preferido escribir el codigo como sigue para que se vea todo más limpio.

# Procesa al primer usuario
# al principio he puesto difentes nombres a las variables, pero al darme cuenta de que son de un solo uso solo he cambiado los indices a los que apunta cuando asigno valores.

usuario_nombre = usuarios[0][1] # guardo la variable apuntando al string que necesito
usuario_nombre = usuario_nombre.strip() # aplico strip para quitar espacios a los lados si corresponde           
usuario_nombre = usuario_nombre.replace('_',' ') # aplico replace para limpiar el guion bajo   
usuario_nombre= usuario_nombre.split() # convierto el string en una lista para separar apellido y nombre
usuario_edad = usuarios[0][2] # asigno el valor de la edad de la lista y se guarda en la variable                        
usuario_edad = int(usuario_edad) # convierto el float a entero
usuario_procesado = [usuario_nombre,usuario_edad]
usuarios_limpio.append(usuario_procesado)

# Procesa al segundo usuario

usuario_nombre = usuarios[1][1] # guardo la variable apuntando al string que necesito
usuario_nombre = usuario_nombre.strip() # aplico strip para quitar espacios a los lados si corresponde           
usuario_nombre = usuario_nombre.replace('_',' ') # aplico replace para limpiar el guion bajo   
usuario_nombre= usuario_nombre.split() # convierto el string en una lista para separar apellido y nombre
usuario_edad = usuarios[1][2] # asigno el valor de la edad de la lista y se guarda en la variable                        
usuario_edad = int(usuario_edad) # convierto el float a entero
usuario_procesado = [usuario_nombre,usuario_edad]
usuarios_limpio.append(usuario_procesado)

# Procesa al tercer usuario

usuario_nombre = usuarios[2][1] # guardo la variable apuntando al string que necesito
usuario_nombre = usuario_nombre.strip() # aplico strip para quitar espacios a los lados si corresponde           
usuario_nombre = usuario_nombre.replace('_',' ') # aplico replace para limpiar el guion bajo   
usuario_nombre= usuario_nombre.split() # convierto el string en una lista para separar apellido y nombre
usuario_edad = usuarios[2][2] # asigno el valor de la edad de la lista y se guarda en la variable                        
usuario_edad = int(usuario_edad) # convierto el float a entero
usuario_procesado = [usuario_nombre,usuario_edad]
usuarios_limpio.append(usuario_procesado)

print(usuarios_limpio,'\n')

# Me he venido arriba he estado trasteando con funciones, repeticiones...
#
usuarios_1 = [ 

    ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['ROPA', 'ELECTRÓNICA', 'BELLEZA'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['LIBROS', 'HOGAR', 'DEPORTE'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BELLEZA', 'HOGAR', 'COMIDA'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['ROPA', 'COMIDA', 'BELLEZA'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['DEPORTE', 'ELECTRÓNICA', 'HOGAR'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOGAR', 'LIBROS', 'ROPA'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BELLEZA', 'ROPA', 'ELECTRÓNICA'], [189, 299, 579]],
]
def ordenar_por_fila (lista,fila): # fila tiene que ser el indice de la fila que quieras ordenar 
    m0 = lista
    m0.sort(key=lambda x:x[fila])
    return m0    

print(ordenar_por_fila(usuarios_1,0),'\n')


def editar_nombre_edad(nombre_completo,edad): # edita los valores nombre_completo(formatea para una mejor visualización) y edad(cambia a entero) según las especificaciones requeridas
    m0 = nombre_completo.strip()
    m1 = m0.replace('_',' ')
    m1 = m1.lower()
    m1 = m1.split()              # me puse nostálgico parece AWL :)
    m1[0] = m1[0].capitalize()
    m1[1] = m1[1].capitalize()
    m2 = edad                        
    m2 = int(m2)
    return m1,m2

print('Esto es una lista nombre de usuario formateada como pide el cliente', editar_nombre_edad(usuarios_1[3][1], usuarios_1[3][2]),'\n')

def sustituir(lista,adicion,indice1,indice2): #lista es la lista a modificar, adicion es lo que queremos sustituir, los indices es la dirección de lo que queremos sustituir.
    m0 = lista
    lista[indice1][indice2] = adicion
    return m0

print(sustituir(usuarios_1,'ESTO ESTA ESCRITO EN MAYUSCULAS PARA QUE SE VEA A SIMPLE VISTA LA SUSTITUCION DEL ELEMENTO DE LA LISTA',1,0),'\n')

def media_gastos(lista): #aqui me vine un poco arriba pero queria probar el for, dot me hechó una mano, importante hay que iniciar las variables antes del bucle
    m0 = lista
    m1 = len(lista)
    m2 = 0
    for i in range(m1):
        m2 = m2 + sum(lista[i-1][-1]) # he decidido dejarlo con el i-1 (resulta que así recorre la lista 9,0,1,2,3...), i inicializa en 0 a no ser que indiques diferente en range(a,b)
    m3 = m2/m1
    return m3
    

print('Esta es la media de gasto de todos los usuarios = ', media_gastos(usuarios_1))
# Out:
# [[['mike', 'reed'], 32], [['kate', 'morgan'], 24], [['john', 'doe'], 37]]
#
# [['31980', 'kate morgan', 24.0, ['ROPA', 'LIBROS'], [439, 390]], ['32156', ' john doe ', 37.0, ['ELECTRÓNICA', 'HOGAR', 'COMIDA'], [459, 120, 99]], ['32415', ' mike_reed ', 32.0, ['ELECTRÓNICA', 'DEPORTE', 'LIBROS'], [894, 213, 173]], ['32761', 'SAMANTHA SMITH', 29.0, ['ROPA', 'ELECTRÓNICA', 'BELLEZA'], [299, 679, 85]], ['32984', 'David White', 41.0, ['LIBROS', 'HOGAR', 'DEPORTE'], [234, 329, 243]], ['33001', 'emily brown', 26.0, ['BELLEZA', 'HOGAR', 'COMIDA'], [213, 659, 79]], ['33767', ' Maria Garcia', 33.0, ['ROPA', 'COMIDA', 'BELLEZA'], [499, 189, 63]], ['33912', 'JOSE MARTINEZ', 22.0, ['DEPORTE', 'ELECTRÓNICA', 'HOGAR'], [259, 549, 109]], ['34009', 'lisa wilson ', 35.0, ['HOGAR', 'LIBROS', 'ROPA'], [329, 189, 329]], ['34278', 'James Lee', 28.0, ['BELLEZA', 'ROPA', 'ELECTRÓNICA'], [189, 299, 579]]]
#
# Esto es una lista nombre de usuario formateada como pide el cliente (['Samantha', 'Smith'], 29)
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# `usuarios_limpio = usuarios` hace que ambos nombres referencien la misma lista anidada, por lo que tu limpieza modifica los datos originales *in-place*. Para esta tarea, crea un `usuarios_limpio` independiente y constrúyelo como una nueva lista de registros de usuario limpiados (por ejemplo, creando un registro limpio por cada usuario y añadiéndolo a `usuarios_limpio`), de modo que la entrada en bruto (raw input) permanezca sin cambios.
#
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 2</b> <a class="tocSkip"></a>
#
# Buen trabajo
#
# </div>

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
#
# Para procesar a cada usuario, comienza por acceder a los elementos requeridos de la lista de usuarios. Por ejemplo, si tienes la lista numeros = [10, 20, 30], puedes acceder a los elementos con numeros[0], numeros[1], etc.
#
# Utiliza el método `strip()` para eliminar los espacios iniciales y finales y el método `replace('_',' ')` para reemplazar los guiones bajos por espacios en los nombres.
#
# Convierte la edad a un número entero utilizando `int()`.
#
# Separa el nombre completo en nombre y apellido utilizando el método `split()`.
#
# Por último, `append` (agrega) los datos limpios a la lista `users_clean`.
