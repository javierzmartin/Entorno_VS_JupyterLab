# %%
books = {
        'George Orwell': '1984',
    'Leo Tolstoy': 'Guerra y paz',
    'Ralph Ellison': 'El hombre invisible',
    'Antoine de Saint-Exupéry': 'El principito'
}

for elemento in books:
    print(elemento)
# Out:
# George Orwell
# Leo Tolstoy
# Ralph Ellison
# Antoine de Saint-Exupéry

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
id(rgb) == id(rgba)  # they reference the same object

rgba.append("Alph")
rgb
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
def greeting(): 
    return '¡Bienvenidos!'
    print('Por favor, esperen..')

print(greeting())
# Out:
# ¡Bienvenidos!

# %%
def send_message(text, source='email'):
    if source == 'email':
        return 'Message sent via email'
    elif source == 'sms':
        return 'Message sent via sms'
    else:
        return 'Unknown source'

print(send_message('Hola'))
# Out:
# Message sent via email
